# %%
import sagemaker
import boto3
from sagemaker.estimator import Estimator
# Out:
# /opt/conda/lib/python3.11/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "json" in "MonitoringDatasetFormat" shadows an attribute in parent "Base"
#   warnings.warn(
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml

# %%
sess = sagemaker.Session()
bucket = sess.default_bucket()
role = sagemaker.get_execution_role()
region = boto3.Session().region_name

sm = boto3.Session().client(service_name="sagemaker", region_name=region)
s3 = boto3.Session().client(service_name="s3", region_name=region)

# %%
bucket_name = 'ads-508-final'

# %%
# Get SageMaker's built-in Factorization Machines container
container = sagemaker.image_uris.retrieve("factorization-machines", region)

fm_estimator = Estimator(
    image_uri=container,
    role=role,
    instance_count=1,
    instance_type="ml.m5.large",
    output_path=f"s3://{bucket_name}/factorization-machines/output",
    sagemaker_session=sess
)
# Out:
# [04/01/25 04:50:23] INFO     Same images used for training and inference. Defaulting to image     ]8;id=735949;file:///opt/conda/lib/python3.11/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=811705;file:///opt/conda/lib/python3.11/site-packages/sagemaker/image_uris.py#393\393]8;;\
#                              scope: inference.
#                     INFO     Ignoring unnecessary instance type: None.                            ]8;id=978097;file:///opt/conda/lib/python3.11/site-packages/sagemaker/image_uris.py\image_uris.py]8;;\:]8;id=831116;file:///opt/conda/lib/python3.11/site-packages/sagemaker/image_uris.py#530\530]8;;\

# %%
# Set hyperparameters 
# (may look at hyper parameter tuning
fm_estimator.set_hyperparameters(
    feature_dim=2,
    num_factors=64,
    predictor_type="binary_classifier",
    mini_batch_size=1000,
    epochs=10
)

# %%
s3_train_path = f"s3://{bucket_name}/transformeddata/sm_fm_train.recordio"
s3_test_path = f"s3://{bucket_name}/transformeddata/sm_fm_test.recordio"

# %%
train_input = sagemaker.inputs.TrainingInput(s3_train_path, content_type="application/x-recordio-protobuf")
test_input = sagemaker.inputs.TrainingInput(s3_test_path, content_type="application/x-recordio-protobuf")

data_channels = {"train": train_input, "test": test_input}

# %%
fm_estimator.fit(inputs=data_channels)
# Out:
#                     INFO     SageMaker Python SDK will collect telemetry to help us better  ]8;id=778626;file:///opt/conda/lib/python3.11/site-packages/sagemaker/telemetry/telemetry_logging.py\telemetry_logging.py]8;;\:]8;id=562121;file:///opt/conda/lib/python3.11/site-packages/sagemaker/telemetry/telemetry_logging.py#91\91]8;;\
#                              understand our user's needs, diagnose issues, and deliver
#                              additional features.
#                              To opt out of telemetry, please disable via TelemetryOptOut
#                              parameter in SDK defaults config. For more information, refer
#                              to
#                              https://sagemaker.readthedocs.io/en/stable/overview.html#confi
#                              guring-and-using-defaults-with-the-sagemaker-python-sdk.
#                     INFO     Creating training-job with name:                                       ]8;id=351540;file:///opt/conda/lib/python3.11/site-packages/sagemaker/session.py\session.py]8;;\:]8;id=423908;file:///opt/conda/lib/python3.11/site-packages/sagemaker/session.py#1042\1042]8;;\
#                              factorization-machines-2025-04-01-04-50-23-673
# 2025-04-01 04:50:28 Starting - Starting the training job...
# ..25-04-01 04:50:42 Starting - Preparing the instances for training.
# ..25-04-01 04:51:03 Downloading - Downloading input data.
# ...........04:51:53 Downloading - Downloading the training image.
# Docker entrypoint called with argument(s): trainmpleted. Training in progress.
# Running default environment configuration script
# /opt/amazon/lib/python3.8/site-packages/mxnet/model.py:97: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if num_device is 1 and 'dist' not in kvstore:
# [04/01/2025 04:53:45 INFO 140639020992320] Reading default configuration from /opt/amazon/lib/python3.8/site-packages/algorithm/resources/default-conf.json: {'epochs': 1, 'mini_batch_size': '1000', 'use_bias': 'true', 'use_linear': 'true', 'bias_lr': '0.1', 'linear_lr': '0.001', 'factors_lr': '0.0001', 'bias_wd': '0.01', 'linear_wd': '0.001', 'factors_wd': '0.00001', 'bias_init_method': 'normal', 'bias_init_sigma': '0.01', 'linear_init_method': 'normal', 'linear_init_sigma': '0.01', 'factors_init_method': 'normal', 'factors_init_sigma': '0.001', 'batch_metrics_publish_interval': '500', '_data_format': 'record', '_kvstore': 'auto', '_learning_rate': '1.0', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_optimizer': 'adam', '_tuning_objective_metric': '', '_use_full_symbolic': 'true', '_wd': '1.0'}
# [04/01/2025 04:53:45 INFO 140639020992320] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '10', 'feature_dim': '2', 'mini_batch_size': '1000', 'num_factors': '64', 'predictor_type': 'binary_classifier'}
# [04/01/2025 04:53:45 INFO 140639020992320] Final configuration: {'epochs': '10', 'mini_batch_size': '1000', 'use_bias': 'true', 'use_linear': 'true', 'bias_lr': '0.1', 'linear_lr': '0.001', 'factors_lr': '0.0001', 'bias_wd': '0.01', 'linear_wd': '0.001', 'factors_wd': '0.00001', 'bias_init_method': 'normal', 'bias_init_sigma': '0.01', 'linear_init_method': 'normal', 'linear_init_sigma': '0.01', 'factors_init_method': 'normal', 'factors_init_sigma': '0.001', 'batch_metrics_publish_interval': '500', '_data_format': 'record', '_kvstore': 'auto', '_learning_rate': '1.0', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_optimizer': 'adam', '_tuning_objective_metric': '', '_use_full_symbolic': 'true', '_wd': '1.0', 'feature_dim': '2', 'num_factors': '64', 'predictor_type': 'binary_classifier'}
# [04/01/2025 04:53:45 WARNING 140639020992320] Loggers have already been setup.
# Process 7 is a worker.
# [04/01/2025 04:53:45 INFO 140639020992320] Using default worker.
# [04/01/2025 04:53:45 INFO 140639020992320] Checkpoint loading and saving are disabled.
# [2025-04-01 04:53:45.065] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2025-04-01 04:53:45.083] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 29, "num_examples": 1, "num_bytes": 60000}
# /opt/amazon/python3.8/lib/python3.8/subprocess.py:848: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdout = io.open(c2pread, 'rb', bufsize)
# [04/01/2025 04:53:45 INFO 140639020992320] nvidia-smi: took 0.034 seconds to run.
# [04/01/2025 04:53:45 INFO 140639020992320] nvidia-smi identified 0 GPUs.
# [04/01/2025 04:53:45 INFO 140639020992320] Number of GPUs being used: 0
# [04/01/2025 04:53:45 INFO 140639020992320] [Sparse network] Building a sparse network.
# [04/01/2025 04:53:45 INFO 140639020992320] Create Store: local
# #metrics {"StartTime": 1743483225.054532, "EndTime": 1743483225.1220558, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 47.58310317993164, "count": 1, "min": 47.58310317993164, "max": 47.58310317993164}}}
# #metrics {"StartTime": 1743483225.1222138, "EndTime": 1743483225.122271, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1000.0, "count": 1, "min": 1000, "max": 1000}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 1000.0, "count": 1, "min": 1000, "max": 1000}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [04:53:45] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_Cuda_11.1.x.406.0/AL2_x86_64/generic-flavor/src/src/kvstore/./kvstore_local.h:306: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use kv.row_sparse_pull() or module.prepare() with row_ids.
# [04:53:45] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_Cuda_11.1.x.406.0/AL2_x86_64/generic-flavor/src/src/kvstore/./kvstore_local.h:306: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use kv.row_sparse_pull() or module.prepare() with row_ids.
# [04:53:45] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_Cuda_11.1.x.406.0/AL2_x86_64/generic-flavor/src/src/operator/././../common/utils.h:450: Optimizer with lazy_update = True detected. Be aware that lazy update with row_sparse gradient is different from standard update, and may lead to different empirical results. See https://mxnet.incubator.apache.org/api/python/optimization/optimization.html for more details.
# [04/01/2025 04:53:45 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.979
# [04/01/2025 04:53:45 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.37767141723632813
# [04/01/2025 04:53:45 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_f_1.000 <score>=0.989388580090955
# [04/01/2025 04:53:47 INFO 140639020992320] Iter[0] Batch [500]#011Speed: 181144.85 samples/sec
# [04/01/2025 04:53:47 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=500 train binary_classification_accuracy <score>=0.9526966067864271
# [04/01/2025 04:53:47 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=500 train binary_classification_cross_entropy <loss>=0.7828038288047927
# [04/01/2025 04:53:47 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=500 train binary_f_1.000 <score>=0.9757295025976672
# [04/01/2025 04:53:50 INFO 140639020992320] Iter[0] Batch [1000]#011Speed: 187003.21 samples/sec
# [04/01/2025 04:53:50 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=1000 train binary_classification_accuracy <score>=0.9527912087912088
# [04/01/2025 04:53:50 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=1000 train binary_classification_cross_entropy <loss>=0.7094442155134905
# [04/01/2025 04:53:50 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=1000 train binary_f_1.000 <score>=0.9757807102602949
# [04/01/2025 04:53:53 INFO 140639020992320] Iter[0] Batch [1500]#011Speed: 196822.68 samples/sec
# [04/01/2025 04:53:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=1500 train binary_classification_accuracy <score>=0.9532598267821453
# [04/01/2025 04:53:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=1500 train binary_classification_cross_entropy <loss>=0.6383316423389452
# [04/01/2025 04:53:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=1500 train binary_f_1.000 <score>=0.9760264130788753
# [04/01/2025 04:53:55 INFO 140639020992320] Iter[0] Batch [2000]#011Speed: 193731.48 samples/sec
# [04/01/2025 04:53:55 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=2000 train binary_classification_accuracy <score>=0.9560369815092454
# [04/01/2025 04:53:55 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=2000 train binary_classification_cross_entropy <loss>=0.547931051979656
# [04/01/2025 04:53:55 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=2000 train binary_f_1.000 <score>=0.9774859968889369
# [04/01/2025 04:53:58 INFO 140639020992320] Iter[0] Batch [2500]#011Speed: 172017.93 samples/sec
# [04/01/2025 04:53:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=2500 train binary_classification_accuracy <score>=0.9575069972011195
# [04/01/2025 04:53:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=2500 train binary_classification_cross_entropy <loss>=0.492391003300218
# [04/01/2025 04:53:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=2500 train binary_f_1.000 <score>=0.9782568177228776
# [04/01/2025 04:54:01 INFO 140639020992320] Iter[0] Batch [3000]#011Speed: 187925.10 samples/sec
# [04/01/2025 04:54:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=3000 train binary_classification_accuracy <score>=0.9591076307897367
# [04/01/2025 04:54:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=3000 train binary_classification_cross_entropy <loss>=0.4454096486092567
# [04/01/2025 04:54:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=3000 train binary_f_1.000 <score>=0.9790948779572065
# [04/01/2025 04:54:04 INFO 140639020992320] Iter[0] Batch [3500]#011Speed: 182100.09 samples/sec
# [04/01/2025 04:54:04 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=3500 train binary_classification_accuracy <score>=0.959567266495287
# [04/01/2025 04:54:04 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=3500 train binary_classification_cross_entropy <loss>=0.4272453596065535
# [04/01/2025 04:54:04 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=3500 train binary_f_1.000 <score>=0.9793347740328965
# [04/01/2025 04:54:07 INFO 140639020992320] Iter[0] Batch [4000]#011Speed: 145047.52 samples/sec
# [04/01/2025 04:54:07 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=4000 train binary_classification_accuracy <score>=0.9597595601099725
# [04/01/2025 04:54:07 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=4000 train binary_classification_cross_entropy <loss>=0.42072236119780176
# [04/01/2025 04:54:07 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=4000 train binary_f_1.000 <score>=0.9794346883193291
# [04/01/2025 04:54:10 INFO 140639020992320] Iter[0] Batch [4500]#011Speed: 148959.25 samples/sec
# [04/01/2025 04:54:10 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=4500 train binary_classification_accuracy <score>=0.9600970895356588
# [04/01/2025 04:54:10 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=4500 train binary_classification_cross_entropy <loss>=0.41035480486554743
# [04/01/2025 04:54:10 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=4500 train binary_f_1.000 <score>=0.9796104364213281
# [04/01/2025 04:54:13 INFO 140639020992320] Iter[0] Batch [5000]#011Speed: 161487.82 samples/sec
# [04/01/2025 04:54:13 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=5000 train binary_classification_accuracy <score>=0.9600981803639272
# [04/01/2025 04:54:13 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=5000 train binary_classification_cross_entropy <loss>=0.4149353814463548
# [04/01/2025 04:54:13 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=5000 train binary_f_1.000 <score>=0.9796103540071041
# [04/01/2025 04:54:16 INFO 140639020992320] Iter[0] Batch [5500]#011Speed: 164826.95 samples/sec
# [04/01/2025 04:54:16 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=5500 train binary_classification_accuracy <score>=0.9602057807671333
# [04/01/2025 04:54:16 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=5500 train binary_classification_cross_entropy <loss>=0.4139714449750924
# [04/01/2025 04:54:16 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=5500 train binary_f_1.000 <score>=0.9796659579891194
# [04/01/2025 04:54:19 INFO 140639020992320] Iter[0] Batch [6000]#011Speed: 177939.28 samples/sec
# [04/01/2025 04:54:19 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=6000 train binary_classification_accuracy <score>=0.9603582736210632
# [04/01/2025 04:54:19 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=6000 train binary_classification_cross_entropy <loss>=0.4130664671351365
# [04/01/2025 04:54:19 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=6000 train binary_f_1.000 <score>=0.9797455580967619
# [04/01/2025 04:54:22 INFO 140639020992320] Iter[0] Batch [6500]#011Speed: 181609.06 samples/sec
# [04/01/2025 04:54:22 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=6500 train binary_classification_accuracy <score>=0.9603596369789263
# [04/01/2025 04:54:22 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=6500 train binary_classification_cross_entropy <loss>=0.41569374333739445
# [04/01/2025 04:54:22 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=6500 train binary_f_1.000 <score>=0.9797461760495557
# [04/01/2025 04:54:25 INFO 140639020992320] Iter[0] Batch [7000]#011Speed: 199558.07 samples/sec
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=7000 train binary_classification_accuracy <score>=0.9601518354520783
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=7000 train binary_classification_cross_entropy <loss>=0.43000669007886394
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, batch=7000 train binary_f_1.000 <score>=0.9796376353506363
# [2025-04-01 04:54:25.665] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 40532, "num_examples": 7141, "num_bytes": 428437620}
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.9599241002660692
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.4359357290819502
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=0, train binary_f_1.000 <score>=0.9795187153605126
# #metrics {"StartTime": 1743483225.1221468, "EndTime": 1743483265.6661587, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "update.time": {"sum": 40543.55192184448, "count": 1, "min": 40543.55192184448, "max": 40543.55192184448}}}
# [04/01/2025 04:54:25 INFO 140639020992320] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1743483225.1225832, "EndTime": 1743483265.666586, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 7141627.0, "count": 1, "min": 7141627, "max": 7141627}, "Total Batches Seen": {"sum": 7142.0, "count": 1, "min": 7142, "max": 7142}, "Max Records Seen Between Resets": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Max Batches Seen Between Resets": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Number of Batches Since Last Reset": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}}}
# [04/01/2025 04:54:25 INFO 140639020992320] #throughput_metric: host=algo-1, train throughput=176119.9330734431 records/second
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.979
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_cross_entropy <loss>=0.36180059814453125
# [04/01/2025 04:54:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_f_1.000 <score>=0.989388580090955
# [04/01/2025 04:54:28 INFO 140639020992320] Iter[1] Batch [500]#011Speed: 207436.20 samples/sec
# [04/01/2025 04:54:28 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=500 train binary_classification_accuracy <score>=0.9504091816367265
# [04/01/2025 04:54:28 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=500 train binary_classification_cross_entropy <loss>=0.6132915682459544
# [04/01/2025 04:54:28 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=500 train binary_f_1.000 <score>=0.9745258652951955
# [04/01/2025 04:54:30 INFO 140639020992320] Iter[1] Batch [1000]#011Speed: 216974.63 samples/sec
# [04/01/2025 04:54:30 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=1000 train binary_classification_accuracy <score>=0.9537772227772228
# [04/01/2025 04:54:30 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=1000 train binary_classification_cross_entropy <loss>=0.5106204182551457
# [04/01/2025 04:54:30 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=1000 train binary_f_1.000 <score>=0.9762962424095875
# [04/01/2025 04:54:32 INFO 140639020992320] Iter[1] Batch [1500]#011Speed: 213663.03 samples/sec
# [04/01/2025 04:54:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=1500 train binary_classification_accuracy <score>=0.9580699533644237
# [04/01/2025 04:54:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=1500 train binary_classification_cross_entropy <loss>=0.4159104208288631
# [04/01/2025 04:54:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=1500 train binary_f_1.000 <score>=0.9785508854571547
# [04/01/2025 04:54:35 INFO 140639020992320] Iter[1] Batch [2000]#011Speed: 182394.57 samples/sec
# [04/01/2025 04:54:35 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=2000 train binary_classification_accuracy <score>=0.9598450774612693
# [04/01/2025 04:54:35 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=2000 train binary_classification_cross_entropy <loss>=0.37428082672302154
# [04/01/2025 04:54:35 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=2000 train binary_f_1.000 <score>=0.979479402530099
# [04/01/2025 04:54:38 INFO 140639020992320] Iter[1] Batch [2500]#011Speed: 158484.71 samples/sec
# [04/01/2025 04:54:38 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=2500 train binary_classification_accuracy <score>=0.9599664134346262
# [04/01/2025 04:54:38 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=2500 train binary_classification_cross_entropy <loss>=0.37104172103131405
# [04/01/2025 04:54:38 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=2500 train binary_f_1.000 <score>=0.9795419977099068
# [04/01/2025 04:54:41 INFO 140639020992320] Iter[1] Batch [3000]#011Speed: 188544.87 samples/sec
# [04/01/2025 04:54:41 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=3000 train binary_classification_accuracy <score>=0.9604905031656115
# [04/01/2025 04:54:41 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=3000 train binary_classification_cross_entropy <loss>=0.3638734387401262
# [04/01/2025 04:54:41 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=3000 train binary_f_1.000 <score>=0.9798152580633079
# [04/01/2025 04:54:43 INFO 140639020992320] Iter[1] Batch [3500]#011Speed: 208157.14 samples/sec
# [04/01/2025 04:54:43 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=3500 train binary_classification_accuracy <score>=0.960883747500714
# [04/01/2025 04:54:43 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=3500 train binary_classification_cross_entropy <loss>=0.3594447309705946
# [04/01/2025 04:54:43 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=3500 train binary_f_1.000 <score>=0.9800197780066116
# [04/01/2025 04:54:46 INFO 140639020992320] Iter[1] Batch [4000]#011Speed: 207398.07 samples/sec
# [04/01/2025 04:54:46 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=4000 train binary_classification_accuracy <score>=0.9608887778055486
# [04/01/2025 04:54:46 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=4000 train binary_classification_cross_entropy <loss>=0.36488907993414854
# [04/01/2025 04:54:46 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=4000 train binary_f_1.000 <score>=0.9800218824247361
# [04/01/2025 04:54:48 INFO 140639020992320] Iter[1] Batch [4500]#011Speed: 194629.69 samples/sec
# [04/01/2025 04:54:48 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=4500 train binary_classification_accuracy <score>=0.9609417907131749
# [04/01/2025 04:54:48 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=4500 train binary_classification_cross_entropy <loss>=0.3763692814475879
# [04/01/2025 04:54:48 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=4500 train binary_f_1.000 <score>=0.9800493814719273
# [04/01/2025 04:54:50 INFO 140639020992320] Iter[1] Batch [5000]#011Speed: 218139.26 samples/sec
# [04/01/2025 04:54:50 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=5000 train binary_classification_accuracy <score>=0.9601747650469906
# [04/01/2025 04:54:50 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=5000 train binary_classification_cross_entropy <loss>=0.41842423169876525
# [04/01/2025 04:54:50 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=5000 train binary_f_1.000 <score>=0.9796491286868749
# [04/01/2025 04:54:53 INFO 140639020992320] Iter[1] Batch [5500]#011Speed: 220681.95 samples/sec
# [04/01/2025 04:54:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=5500 train binary_classification_accuracy <score>=0.9594346482457735
# [04/01/2025 04:54:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=5500 train binary_classification_cross_entropy <loss>=0.45166290161016315
# [04/01/2025 04:54:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=5500 train binary_f_1.000 <score>=0.9792625516159411
# [04/01/2025 04:54:55 INFO 140639020992320] Iter[1] Batch [6000]#011Speed: 210313.37 samples/sec
# [04/01/2025 04:54:55 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=6000 train binary_classification_accuracy <score>=0.958811698050325
# [04/01/2025 04:54:55 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=6000 train binary_classification_cross_entropy <loss>=0.47808592881792444
# [04/01/2025 04:54:55 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=6000 train binary_f_1.000 <score>=0.9789374090706396
# [04/01/2025 04:54:58 INFO 140639020992320] Iter[1] Batch [6500]#011Speed: 187405.81 samples/sec
# [04/01/2025 04:54:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=6500 train binary_classification_accuracy <score>=0.9582015074603907
# [04/01/2025 04:54:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=6500 train binary_classification_cross_entropy <loss>=0.49910736662672955
# [04/01/2025 04:54:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=6500 train binary_f_1.000 <score>=0.9786183493546996
# [04/01/2025 04:55:00 INFO 140639020992320] Iter[1] Batch [7000]#011Speed: 198816.48 samples/sec
# [04/01/2025 04:55:00 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=7000 train binary_classification_accuracy <score>=0.9577784602199686
# [04/01/2025 04:55:00 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=7000 train binary_classification_cross_entropy <loss>=0.514872147570881
# [04/01/2025 04:55:00 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, batch=7000 train binary_f_1.000 <score>=0.9783970825723838
# [2025-04-01 04:55:01.672] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 36004, "num_examples": 7141, "num_bytes": 428437620}
# [04/01/2025 04:55:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, train binary_classification_accuracy <score>=0.9575999159781543
# [04/01/2025 04:55:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy <loss>=0.5198604783283998
# [04/01/2025 04:55:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=1, train binary_f_1.000 <score>=0.9783036536873915
# #metrics {"StartTime": 1743483265.666227, "EndTime": 1743483301.6735382, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 36006.52313232422, "count": 1, "min": 36006.52313232422, "max": 36006.52313232422}}}
# [04/01/2025 04:55:01 INFO 140639020992320] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1743483265.6669893, "EndTime": 1743483301.6738353, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 14282254.0, "count": 1, "min": 14282254, "max": 14282254}, "Total Batches Seen": {"sum": 14283.0, "count": 1, "min": 14283, "max": 14283}, "Max Records Seen Between Resets": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Max Batches Seen Between Resets": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Number of Batches Since Last Reset": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}}}
# [04/01/2025 04:55:01 INFO 140639020992320] #throughput_metric: host=algo-1, train throughput=198312.16845477602 records/second
# [04/01/2025 04:55:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_accuracy <score>=0.979
# [04/01/2025 04:55:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_cross_entropy <loss>=0.37067294311523435
# [04/01/2025 04:55:01 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_f_1.000 <score>=0.989388580090955
# [04/01/2025 04:55:04 INFO 140639020992320] Iter[2] Batch [500]#011Speed: 174637.95 samples/sec
# [04/01/2025 04:55:04 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=500 train binary_classification_accuracy <score>=0.9520259481037924
# [04/01/2025 04:55:04 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=500 train binary_classification_cross_entropy <loss>=0.7245356733737116
# [04/01/2025 04:55:04 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=500 train binary_f_1.000 <score>=0.9753787936991839
# [04/01/2025 04:55:07 INFO 140639020992320] Iter[2] Batch [1000]#011Speed: 183972.10 samples/sec
# [04/01/2025 04:55:07 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=1000 train binary_classification_accuracy <score>=0.9519210789210789
# [04/01/2025 04:55:07 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=1000 train binary_classification_cross_entropy <loss>=0.7076431642698122
# [04/01/2025 04:55:07 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=1000 train binary_f_1.000 <score>=0.9753220056004541
# [04/01/2025 04:55:09 INFO 140639020992320] Iter[2] Batch [1500]#011Speed: 194969.85 samples/sec
# [04/01/2025 04:55:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=1500 train binary_classification_accuracy <score>=0.9515696202531646
# [04/01/2025 04:55:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=1500 train binary_classification_cross_entropy <loss>=0.6877720455040064
# [04/01/2025 04:55:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=1500 train binary_f_1.000 <score>=0.9751366740726959
# [04/01/2025 04:55:12 INFO 140639020992320] Iter[2] Batch [2000]#011Speed: 203916.90 samples/sec
# [04/01/2025 04:55:12 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=2000 train binary_classification_accuracy <score>=0.9517171414292853
# [04/01/2025 04:55:12 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=2000 train binary_classification_cross_entropy <loss>=0.6895902361548107
# [04/01/2025 04:55:12 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=2000 train binary_f_1.000 <score>=0.9752146724295747
# [04/01/2025 04:55:14 INFO 140639020992320] Iter[2] Batch [2500]#011Speed: 213381.61 samples/sec
# [04/01/2025 04:55:14 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=2500 train binary_classification_accuracy <score>=0.9515449820071972
# [04/01/2025 04:55:14 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=2500 train binary_classification_cross_entropy <loss>=0.6880736381686339
# [04/01/2025 04:55:14 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=2500 train binary_f_1.000 <score>=0.9751238205029674
# [04/01/2025 04:55:17 INFO 140639020992320] Iter[2] Batch [3000]#011Speed: 209381.84 samples/sec
# [04/01/2025 04:55:17 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=3000 train binary_classification_accuracy <score>=0.9518000666444518
# [04/01/2025 04:55:17 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=3000 train binary_classification_cross_entropy <loss>=0.6767319976211746
# [04/01/2025 04:55:17 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=3000 train binary_f_1.000 <score>=0.9752582736689999
# [04/01/2025 04:55:19 INFO 140639020992320] Iter[2] Batch [3500]#011Speed: 205149.35 samples/sec
# [04/01/2025 04:55:19 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=3500 train binary_classification_accuracy <score>=0.9518628963153385
# [04/01/2025 04:55:19 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=3500 train binary_classification_cross_entropy <loss>=0.6619109700934882
# [04/01/2025 04:55:19 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=3500 train binary_f_1.000 <score>=0.9752905987918598
# [04/01/2025 04:55:21 INFO 140639020992320] Iter[2] Batch [4000]#011Speed: 200630.97 samples/sec
# [04/01/2025 04:55:21 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=4000 train binary_classification_accuracy <score>=0.9526205948512871
# [04/01/2025 04:55:21 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=4000 train binary_classification_cross_entropy <loss>=0.6340825200728016
# [04/01/2025 04:55:21 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=4000 train binary_f_1.000 <score>=0.9756890558879192
# [04/01/2025 04:55:24 INFO 140639020992320] Iter[2] Batch [4500]#011Speed: 188667.56 samples/sec
# [04/01/2025 04:55:24 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=4500 train binary_classification_accuracy <score>=0.9528007109531216
# [04/01/2025 04:55:24 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=4500 train binary_classification_cross_entropy <loss>=0.6250154432776874
# [04/01/2025 04:55:24 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=4500 train binary_f_1.000 <score>=0.9757833997898014
# [04/01/2025 04:55:27 INFO 140639020992320] Iter[2] Batch [5000]#011Speed: 190254.35 samples/sec
# [04/01/2025 04:55:27 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=5000 train binary_classification_accuracy <score>=0.9530695860827835
# [04/01/2025 04:55:27 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=5000 train binary_classification_cross_entropy <loss>=0.6083680222009187
# [04/01/2025 04:55:27 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=5000 train binary_f_1.000 <score>=0.9759247544329877
# [04/01/2025 04:55:29 INFO 140639020992320] Iter[2] Batch [5500]#011Speed: 201762.74 samples/sec
# [04/01/2025 04:55:29 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=5500 train binary_classification_accuracy <score>=0.9532368660243592
# [04/01/2025 04:55:29 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=5500 train binary_classification_cross_entropy <loss>=0.607815731660905
# [04/01/2025 04:55:29 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=5500 train binary_f_1.000 <score>=0.9760122909453868
# [04/01/2025 04:55:32 INFO 140639020992320] Iter[2] Batch [6000]#011Speed: 205828.62 samples/sec
# [04/01/2025 04:55:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=6000 train binary_classification_accuracy <score>=0.953065322446259
# [04/01/2025 04:55:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=6000 train binary_classification_cross_entropy <loss>=0.6172510968974145
# [04/01/2025 04:55:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=6000 train binary_f_1.000 <score>=0.9759225088702159
# [04/01/2025 04:55:34 INFO 140639020992320] Iter[2] Batch [6500]#011Speed: 214308.04 samples/sec
# [04/01/2025 04:55:34 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=6500 train binary_classification_accuracy <score>=0.9529704660821412
# [04/01/2025 04:55:34 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=6500 train binary_classification_cross_entropy <loss>=0.6204991798899647
# [04/01/2025 04:55:34 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=6500 train binary_f_1.000 <score>=0.9758726960555035
# [04/01/2025 04:55:36 INFO 140639020992320] Iter[2] Batch [7000]#011Speed: 214720.53 samples/sec
# [04/01/2025 04:55:36 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=7000 train binary_classification_accuracy <score>=0.9537448935866305
# [04/01/2025 04:55:36 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=7000 train binary_classification_cross_entropy <loss>=0.5965866338203778
# [04/01/2025 04:55:36 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, batch=7000 train binary_f_1.000 <score>=0.9762804194801281
# [2025-04-01 04:55:37.435] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 35758, "num_examples": 7141, "num_bytes": 428437620}
# [04/01/2025 04:55:37 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, train binary_classification_accuracy <score>=0.9540506931802268
# [04/01/2025 04:55:37 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy <loss>=0.5876933718858822
# [04/01/2025 04:55:37 INFO 140639020992320] #quality_metric: host=algo-1, epoch=2, train binary_f_1.000 <score>=0.9764415279994325
# #metrics {"StartTime": 1743483301.6736412, "EndTime": 1743483337.4361827, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 35760.45846939087, "count": 1, "min": 35760.45846939087, "max": 35760.45846939087}}}
# [04/01/2025 04:55:37 INFO 140639020992320] #progress_metric: host=algo-1, completed 30.0 % of epochs
# #metrics {"StartTime": 1743483301.675652, "EndTime": 1743483337.4365768, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 21422881.0, "count": 1, "min": 21422881, "max": 21422881}, "Total Batches Seen": {"sum": 21424.0, "count": 1, "min": 21424, "max": 21424}, "Max Records Seen Between Resets": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Max Batches Seen Between Resets": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Number of Batches Since Last Reset": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}}}
# [04/01/2025 04:55:37 INFO 140639020992320] #throughput_metric: host=algo-1, train throughput=199676.14146172622 records/second
# [04/01/2025 04:55:37 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_accuracy <score>=0.979
# [04/01/2025 04:55:37 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_cross_entropy <loss>=0.11199586486816407
# [04/01/2025 04:55:37 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_f_1.000 <score>=0.989388580090955
# [04/01/2025 04:55:39 INFO 140639020992320] Iter[3] Batch [500]#011Speed: 210401.55 samples/sec
# [04/01/2025 04:55:39 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=500 train binary_classification_accuracy <score>=0.9646007984031936
# [04/01/2025 04:55:39 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=500 train binary_classification_cross_entropy <loss>=0.2462405872002333
# [04/01/2025 04:55:39 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=500 train binary_f_1.000 <score>=0.9819610619325007
# [04/01/2025 04:55:42 INFO 140639020992320] Iter[3] Batch [1000]#011Speed: 211648.46 samples/sec
# [04/01/2025 04:55:42 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=1000 train binary_classification_accuracy <score>=0.9639740259740259
# [04/01/2025 04:55:42 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=1000 train binary_classification_cross_entropy <loss>=0.29003816037935454
# [04/01/2025 04:55:42 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=1000 train binary_f_1.000 <score>=0.9816305988928032
# [04/01/2025 04:55:44 INFO 140639020992320] Iter[3] Batch [1500]#011Speed: 217344.33 samples/sec
# [04/01/2025 04:55:44 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=1500 train binary_classification_accuracy <score>=0.9633550966022651
# [04/01/2025 04:55:44 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=1500 train binary_classification_cross_entropy <loss>=0.30598372130676715
# [04/01/2025 04:55:44 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=1500 train binary_f_1.000 <score>=0.9813082460661817
# [04/01/2025 04:55:46 INFO 140639020992320] Iter[3] Batch [2000]#011Speed: 218188.14 samples/sec
# [04/01/2025 04:55:46 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=2000 train binary_classification_accuracy <score>=0.9629075462268866
# [04/01/2025 04:55:46 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=2000 train binary_classification_cross_entropy <loss>=0.32646363323083943
# [04/01/2025 04:55:46 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=2000 train binary_f_1.000 <score>=0.9810747961426466
# [04/01/2025 04:55:49 INFO 140639020992320] Iter[3] Batch [2500]#011Speed: 210452.37 samples/sec
# [04/01/2025 04:55:49 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=2500 train binary_classification_accuracy <score>=0.962313074770092
# [04/01/2025 04:55:49 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=2500 train binary_classification_cross_entropy <loss>=0.3521304650259037
# [04/01/2025 04:55:49 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=2500 train binary_f_1.000 <score>=0.9807645016229409
# [04/01/2025 04:55:51 INFO 140639020992320] Iter[3] Batch [3000]#011Speed: 209940.15 samples/sec
# [04/01/2025 04:55:51 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=3000 train binary_classification_accuracy <score>=0.9621249583472176
# [04/01/2025 04:55:51 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=3000 train binary_classification_cross_entropy <loss>=0.3606996822083882
# [04/01/2025 04:55:51 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=3000 train binary_f_1.000 <score>=0.9806660033928006
# [04/01/2025 04:55:53 INFO 140639020992320] Iter[3] Batch [3500]#011Speed: 214096.40 samples/sec
# [04/01/2025 04:55:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=3500 train binary_classification_accuracy <score>=0.9619785775492716
# [04/01/2025 04:55:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=3500 train binary_classification_cross_entropy <loss>=0.370160408643272
# [04/01/2025 04:55:53 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=3500 train binary_f_1.000 <score>=0.9805893693502682
# [04/01/2025 04:55:56 INFO 140639020992320] Iter[3] Batch [4000]#011Speed: 219966.77 samples/sec
# [04/01/2025 04:55:56 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=4000 train binary_classification_accuracy <score>=0.9612836790802299
# [04/01/2025 04:55:56 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=4000 train binary_classification_cross_entropy <loss>=0.41103064409716966
# [04/01/2025 04:55:56 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=4000 train binary_f_1.000 <score>=0.9802270524210832
# [04/01/2025 04:55:58 INFO 140639020992320] Iter[3] Batch [4500]#011Speed: 218100.76 samples/sec
# [04/01/2025 04:55:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=4500 train binary_classification_accuracy <score>=0.9601177516107532
# [04/01/2025 04:55:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=4500 train binary_classification_cross_entropy <loss>=0.44670377245099774
# [04/01/2025 04:55:58 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=4500 train binary_f_1.000 <score>=0.9796189142289067
# [04/01/2025 04:56:00 INFO 140639020992320] Iter[3] Batch [5000]#011Speed: 217616.48 samples/sec
# [04/01/2025 04:56:00 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=5000 train binary_classification_accuracy <score>=0.9592417516496701
# [04/01/2025 04:56:00 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=5000 train binary_classification_cross_entropy <loss>=0.4731151167608885
# [04/01/2025 04:56:00 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=5000 train binary_f_1.000 <score>=0.9791615379519437
# [04/01/2025 04:56:03 INFO 140639020992320] Iter[3] Batch [5500]#011Speed: 188358.90 samples/sec
# [04/01/2025 04:56:03 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=5500 train binary_classification_accuracy <score>=0.9586762406835121
# [04/01/2025 04:56:03 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=5500 train binary_classification_cross_entropy <loss>=0.4854124242092258
# [04/01/2025 04:56:03 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=5500 train binary_f_1.000 <score>=0.9788660585490188
# [04/01/2025 04:56:05 INFO 140639020992320] Iter[3] Batch [6000]#011Speed: 195372.90 samples/sec
# [04/01/2025 04:56:05 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=6000 train binary_classification_accuracy <score>=0.9580074987502083
# [04/01/2025 04:56:05 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=6000 train binary_classification_cross_entropy <loss>=0.49850752724124836
# [04/01/2025 04:56:05 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=6000 train binary_f_1.000 <score>=0.9785164567179456
# [04/01/2025 04:56:08 INFO 140639020992320] Iter[3] Batch [6500]#011Speed: 202565.02 samples/sec
# [04/01/2025 04:56:08 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=6500 train binary_classification_accuracy <score>=0.9575989847715736
# [04/01/2025 04:56:08 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=6500 train binary_classification_cross_entropy <loss>=0.50799304977532
# [04/01/2025 04:56:08 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=6500 train binary_f_1.000 <score>=0.9783027809300234
# [04/01/2025 04:56:10 INFO 140639020992320] Iter[3] Batch [7000]#011Speed: 197248.39 samples/sec
# [04/01/2025 04:56:10 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=7000 train binary_classification_accuracy <score>=0.9572663905156407
# [04/01/2025 04:56:10 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=7000 train binary_classification_cross_entropy <loss>=0.5136674218136248
# [04/01/2025 04:56:10 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, batch=7000 train binary_f_1.000 <score>=0.9781287699028574
# [2025-04-01 04:56:11.611] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 34167, "num_examples": 7141, "num_bytes": 428437620}
# [04/01/2025 04:56:11 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, train binary_classification_accuracy <score>=0.9570904635205153
# [04/01/2025 04:56:11 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, train binary_classification_cross_entropy <loss>=0.5173298214628088
# [04/01/2025 04:56:11 INFO 140639020992320] #quality_metric: host=algo-1, epoch=3, train binary_f_1.000 <score>=0.9780367129234373
# #metrics {"StartTime": 1743483337.4362476, "EndTime": 1743483371.611739, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 34170.20797729492, "count": 1, "min": 34170.20797729492, "max": 34170.20797729492}}}
# [04/01/2025 04:56:11 INFO 140639020992320] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1743483337.4415038, "EndTime": 1743483371.6120448, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 28563508.0, "count": 1, "min": 28563508, "max": 28563508}, "Total Batches Seen": {"sum": 28565.0, "count": 1, "min": 28565, "max": 28565}, "Max Records Seen Between Resets": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Max Batches Seen Between Resets": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Number of Batches Since Last Reset": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}}}
# [04/01/2025 04:56:11 INFO 140639020992320] #throughput_metric: host=algo-1, train throughput=208969.35756928028 records/second
# ...
# [04/01/2025 04:59:08 INFO 140639020992320] #quality_metric: host=algo-1, epoch=8, batch=7000 train binary_classification_cross_entropy <loss>=0.4133718238060108
# [04/01/2025 04:59:08 INFO 140639020992320] #quality_metric: host=algo-1, epoch=8, batch=7000 train binary_f_1.000 <score>=0.980353507748852
# [2025-04-01 04:59:09.495] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 35173, "num_examples": 7141, "num_bytes": 428437620}
# [04/01/2025 04:59:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=8, train binary_classification_accuracy <score>=0.961411286934603
# [04/01/2025 04:59:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy <loss>=0.4153718872294675
# [04/01/2025 04:59:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=8, train binary_f_1.000 <score>=0.9802921343043108
# #metrics {"StartTime": 1743483514.3192296, "EndTime": 1743483549.4967606, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 35175.551414489746, "count": 1, "min": 35175.551414489746, "max": 35175.551414489746}}}
# [04/01/2025 04:59:09 INFO 140639020992320] #progress_metric: host=algo-1, completed 90.0 % of epochs
# #metrics {"StartTime": 1743483514.3211844, "EndTime": 1743483549.497107, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 64266643.0, "count": 1, "min": 64266643, "max": 64266643}, "Total Batches Seen": {"sum": 64270.0, "count": 1, "min": 64270, "max": 64270}, "Max Records Seen Between Resets": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Max Batches Seen Between Resets": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Number of Batches Since Last Reset": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}}}
# [04/01/2025 04:59:09 INFO 140639020992320] #throughput_metric: host=algo-1, train throughput=202996.9780698516 records/second
# [04/01/2025 04:59:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_accuracy <score>=0.979
# [04/01/2025 04:59:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_cross_entropy <loss>=0.36275820922851565
# [04/01/2025 04:59:09 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_f_1.000 <score>=0.989388580090955
# [04/01/2025 04:59:11 INFO 140639020992320] Iter[9] Batch [500]#011Speed: 209515.34 samples/sec
# [04/01/2025 04:59:11 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=500 train binary_classification_accuracy <score>=0.9607604790419162
# [04/01/2025 04:59:11 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=500 train binary_classification_cross_entropy <loss>=0.4144989924021586
# [04/01/2025 04:59:11 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=500 train binary_f_1.000 <score>=0.9799528674670291
# [04/01/2025 04:59:14 INFO 140639020992320] Iter[9] Batch [1000]#011Speed: 220826.71 samples/sec
# [04/01/2025 04:59:14 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=1000 train binary_classification_accuracy <score>=0.9622347652347653
# [04/01/2025 04:59:14 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=1000 train binary_classification_cross_entropy <loss>=0.3823771048821174
# [04/01/2025 04:59:14 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=1000 train binary_f_1.000 <score>=0.9807219121937488
# [04/01/2025 04:59:16 INFO 140639020992320] Iter[9] Batch [1500]#011Speed: 219064.78 samples/sec
# [04/01/2025 04:59:16 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=1500 train binary_classification_accuracy <score>=0.9618647568287808
# [04/01/2025 04:59:16 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=1500 train binary_classification_cross_entropy <loss>=0.40315287545424633
# [04/01/2025 04:59:16 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=1500 train binary_f_1.000 <score>=0.9805278414006102
# [04/01/2025 04:59:18 INFO 140639020992320] Iter[9] Batch [2000]#011Speed: 220663.88 samples/sec
# [04/01/2025 04:59:18 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=2000 train binary_classification_accuracy <score>=0.9614602698650675
# [04/01/2025 04:59:18 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=2000 train binary_classification_cross_entropy <loss>=0.4270785532564833
# [04/01/2025 04:59:18 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=2000 train binary_f_1.000 <score>=0.9803169683261383
# [04/01/2025 04:59:20 INFO 140639020992320] Iter[9] Batch [2500]#011Speed: 220466.51 samples/sec
# [04/01/2025 04:59:20 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=2500 train binary_classification_accuracy <score>=0.9614434226309476
# [04/01/2025 04:59:20 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=2500 train binary_classification_cross_entropy <loss>=0.42596830080833875
# [04/01/2025 04:59:20 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=2500 train binary_f_1.000 <score>=0.9803085209397836
# [04/01/2025 04:59:23 INFO 140639020992320] Iter[9] Batch [3000]#011Speed: 218798.99 samples/sec
# [04/01/2025 04:59:23 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=3000 train binary_classification_accuracy <score>=0.9615318227257581
# [04/01/2025 04:59:23 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=3000 train binary_classification_cross_entropy <loss>=0.4252700462201483
# [04/01/2025 04:59:23 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=3000 train binary_f_1.000 <score>=0.9803546519414338
# [04/01/2025 04:59:25 INFO 140639020992320] Iter[9] Batch [3500]#011Speed: 219782.08 samples/sec
# [04/01/2025 04:59:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=3500 train binary_classification_accuracy <score>=0.9610462724935732
# [04/01/2025 04:59:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=3500 train binary_classification_cross_entropy <loss>=0.4342647038241585
# [04/01/2025 04:59:25 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=3500 train binary_f_1.000 <score>=0.9801013920431539
# [04/01/2025 04:59:27 INFO 140639020992320] Iter[9] Batch [4000]#011Speed: 220416.00 samples/sec
# [04/01/2025 04:59:27 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=4000 train binary_classification_accuracy <score>=0.9610984753811547
# [04/01/2025 04:59:27 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=4000 train binary_classification_cross_entropy <loss>=0.4305262430043734
# [04/01/2025 04:59:27 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=4000 train binary_f_1.000 <score>=0.9801288569799872
# [04/01/2025 04:59:30 INFO 140639020992320] Iter[9] Batch [4500]#011Speed: 220113.33 samples/sec
# [04/01/2025 04:59:30 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=4500 train binary_classification_accuracy <score>=0.9611121972894913
# [04/01/2025 04:59:30 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=4500 train binary_classification_cross_entropy <loss>=0.42944995181938195
# [04/01/2025 04:59:30 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=4500 train binary_f_1.000 <score>=0.9801361419987693
# [04/01/2025 04:59:32 INFO 140639020992320] Iter[9] Batch [5000]#011Speed: 219399.15 samples/sec
# [04/01/2025 04:59:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=5000 train binary_classification_accuracy <score>=0.9609768046390722
# [04/01/2025 04:59:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=5000 train binary_classification_cross_entropy <loss>=0.43368239912808454
# [04/01/2025 04:59:32 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=5000 train binary_f_1.000 <score>=0.9800651118158711
# [04/01/2025 04:59:34 INFO 140639020992320] Iter[9] Batch [5500]#011Speed: 218293.87 samples/sec
# [04/01/2025 04:59:34 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=5500 train binary_classification_accuracy <score>=0.9609216506089802
# [04/01/2025 04:59:34 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=5500 train binary_classification_cross_entropy <loss>=0.4330739298274226
# [04/01/2025 04:59:34 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=5500 train binary_f_1.000 <score>=0.980036051564324
# [04/01/2025 04:59:36 INFO 140639020992320] Iter[9] Batch [6000]#011Speed: 222563.55 samples/sec
# [04/01/2025 04:59:36 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=6000 train binary_classification_accuracy <score>=0.9611424762539577
# [04/01/2025 04:59:36 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=6000 train binary_classification_cross_entropy <loss>=0.42808953093338203
# [04/01/2025 04:59:36 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=6000 train binary_f_1.000 <score>=0.9801514618872557
# [04/01/2025 04:59:39 INFO 140639020992320] Iter[9] Batch [6500]#011Speed: 219841.59 samples/sec
# [04/01/2025 04:59:39 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=6500 train binary_classification_accuracy <score>=0.9612630364559298
# [04/01/2025 04:59:39 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=6500 train binary_classification_cross_entropy <loss>=0.42492933048869697
# [04/01/2025 04:59:39 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=6500 train binary_f_1.000 <score>=0.9802143626713946
# [04/01/2025 04:59:41 INFO 140639020992320] Iter[9] Batch [7000]#011Speed: 220091.64 samples/sec
# [04/01/2025 04:59:41 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=7000 train binary_classification_accuracy <score>=0.9613152406799028
# [04/01/2025 04:59:41 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=7000 train binary_classification_cross_entropy <loss>=0.42427564814349206
# [04/01/2025 04:59:41 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, batch=7000 train binary_f_1.000 <score>=0.9802416536686506
# [2025-04-01 04:59:42.053] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 20, "duration": 32549, "num_examples": 7141, "num_bytes": 428437620}
# [04/01/2025 04:59:42 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, train binary_classification_accuracy <score>=0.961234140876628
# [04/01/2025 04:59:42 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy <loss>=0.42615495807565973
# [04/01/2025 04:59:42 INFO 140639020992320] #quality_metric: host=algo-1, epoch=9, train binary_f_1.000 <score>=0.9801992626804451
# [04/01/2025 04:59:42 INFO 140639020992320] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.961234140876628
# [04/01/2025 04:59:42 INFO 140639020992320] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.42615495807565973
# [04/01/2025 04:59:42 INFO 140639020992320] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.9801992626804451
# #metrics {"StartTime": 1743483549.4968197, "EndTime": 1743483582.0548477, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 32552.58059501648, "count": 1, "min": 32552.58059501648, "max": 32552.58059501648}}}
# [04/01/2025 04:59:42 INFO 140639020992320] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1743483549.5022397, "EndTime": 1743483582.0551803, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 71407270.0, "count": 1, "min": 71407270, "max": 71407270}, "Total Batches Seen": {"sum": 71411.0, "count": 1, "min": 71411, "max": 71411}, "Max Records Seen Between Resets": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Max Batches Seen Between Resets": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 7140627.0, "count": 1, "min": 7140627, "max": 7140627}, "Number of Batches Since Last Reset": {"sum": 7141.0, "count": 1, "min": 7141, "max": 7141}}}
# [04/01/2025 04:59:42 INFO 140639020992320] #throughput_metric: host=algo-1, train throughput=219353.21629153652 records/second
# [04/01/2025 04:59:42 WARNING 140639020992320] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/01/2025 04:59:42 INFO 140639020992320] Pulling entire model from kvstore to finalize
# #metrics {"StartTime": 1743483582.0549586, "EndTime": 1743483582.0576088, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"finalize.time": {"sum": 2.0036697387695312, "count": 1, "min": 2.0036697387695312, "max": 2.0036697387695312}}}
# [04/01/2025 04:59:42 INFO 140639020992320] Saved checkpoint to "/tmp/tmpv4w9sj0p/state-0001.params"
# [2025-04-01 04:59:42.065] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 356999, "num_examples": 1, "num_bytes": 60000}
# [2025-04-01 04:59:47.494] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 5428, "num_examples": 1786, "num_bytes": 107109420}
# #metrics {"StartTime": 1743483582.0607502, "EndTime": 1743483587.4948268, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1785157.0, "count": 1, "min": 1785157, "max": 1785157}, "Total Batches Seen": {"sum": 1786.0, "count": 1, "min": 1786, "max": 1786}, "Max Records Seen Between Resets": {"sum": 1785157.0, "count": 1, "min": 1785157, "max": 1785157}, "Max Batches Seen Between Resets": {"sum": 1786.0, "count": 1, "min": 1786, "max": 1786}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 1785157.0, "count": 1, "min": 1785157, "max": 1785157}, "Number of Batches Since Last Reset": {"sum": 1786.0, "count": 1, "min": 1786, "max": 1786}}}
# [04/01/2025 04:59:47 INFO 140639020992320] #test_score (algo-1) : ('binary_classification_accuracy', 0.9739597133473414)
# [04/01/2025 04:59:47 INFO 140639020992320] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.476090223382482)
# [04/01/2025 04:59:47 INFO 140639020992320] #test_score (algo-1) : ('binary_f_1.000', 0.9868080961953876)
# [04/01/2025 04:59:47 INFO 140639020992320] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.9739597133473414
# [04/01/2025 04:59:47 INFO 140639020992320] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.476090223382482
# [04/01/2025 04:59:47 INFO 140639020992320] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.9868080961953876
# #metrics {"StartTime": 1743483582.057653, "EndTime": 1743483587.503696, "Dimensions": {"Algorithm": "factorization-machines", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 15.831232070922852, "count": 1, "min": 15.831232070922852, "max": 15.831232070922852}, "totaltime": {"sum": 362467.59033203125, "count": 1, "min": 362467.59033203125, "max": 362467.59033203125}}}
#
# 2025-04-01 04:59:56 Uploading - Uploading generated training model
# 2025-04-01 05:00:09 Completed - Training job completed
# Training seconds: 546
# Billable seconds: 546

# %%
training_job_name = 'factorization-machines-2025-04-01-04-50-23-673'

sm_client = boto3.client('sagemaker')
response = sm_client.describe_training_job(TrainingJobName=training_job_name)
metrics = response.get('FinalMetricDataList', [])

# %%
metric_dict = {metric['MetricName']: metric for metric in metrics}

# Create a helper to print nicely
def print_metric(name, metric_dict):
    if name in metric_dict:
        m = metric_dict[name]
        print(f"{name}: {m['Value']:.4f} (timestamp: {m['Timestamp']})")
    else:
        print(f"{name}: Not found")

# Print F1 and Accuracy metrics
print("F1 Scores")
print_metric('train:binary_f_beta:epoch', metric_dict)
print_metric('test:binary_f_beta', metric_dict)

print("\nAccuracy")
print_metric('train:binary_classification_accuracy:epoch', metric_dict)
print_metric('test:binary_classification_accuracy', metric_dict)
# Out:
# 🔍 F1 Scores
# train:binary_f_beta:epoch: 0.9802 (timestamp: 2025-04-01 04:59:42+00:00)
# test:binary_f_beta: 0.9868 (timestamp: 2025-04-01 04:59:47+00:00)
#
# 📊 Accuracy
# train:binary_classification_accuracy:epoch: 0.9612 (timestamp: 2025-04-01 04:59:42+00:00)
# test:binary_classification_accuracy: 0.9740 (timestamp: 2025-04-01 04:59:47+00:00)
